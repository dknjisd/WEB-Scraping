# %%
# !pip install yfinance
# !pip install Beautifulsoup
# !pip install requests
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.0/73.0 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 56.7 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 21.3 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.1-py3-none-any.whl size=136905 sha256=06a9d258c2d4896ab5c0fd61e8752b8cc48028e439a0083adffddc47cf53077d
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/c1/c6/98/596764d33a44aa6fea2b82c3b995bb1db3b013ec7a6321f8ed
# Successfully built peewee
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.29.0
#     Uninstalling requests-2.29.0:
# ...

# %% [markdown]
# ### FINAL ASSIGNMENT

# %% [markdown]
# ### TESLA STOCK ANALYSIS

# %%
import yfinance as yf
import pandas as pd
tesla = yf.Ticker("TSLA")

# %%
tesla_data = tesla.history(period="max")

# %%
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# ### TESLA REVENUE

# %%
import pandas as pd

# Sample HTML content simulating the target website's structure (replace with actual scraping logic)
html_data = '''
<table cellpadding="1" cellspacing="1" border="0" width="100%">
  <tbody>
    <tr>
      <th>Date</th>
      <th>Revenue (USD Billion)</th>
    </tr>
    <tr>
      <td>2010-09-30</td>
      <td>31</td>
    </tr>
    <tr>
      <td>2010-06-30</td>
      <td>28</td>
    </tr>
    <tr>
      <td>2010-03-31</td>
      <td>21</td>
    </tr>
    <tr>
      <td>2009-09-30</td>
      <td>46</td>
    </tr>
    <tr>
      <td>2009-09-30</td>
      <td>27</td>
    </tr>
  </tbody>
</table>
'''

# %%
# Parsing the HTML data (assuming you have the actual scraping logic)
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Extracting the table data
table_data = soup.find('table')
rows = table_data.find_all('tr')

# Creating an empty list to store revenue data
tesla_revenue = []
for row in rows[1:]:  # Skip the header row
  # Extract date and revenue data from each row
  date = row.find_all('td')[0].text.strip()
  revenue = row.find_all('td')[1].text.strip().replace("$", "")  # Remove dollar sign (assuming USD Billion format)
  # Append data to the tesla_revenue list
  tesla_revenue.append([date, revenue])

# Creating a Pandas DataFrame
df = pd.DataFrame(tesla_revenue, columns=['Date', 'Revenue'])

# Displaying the last five rows of the DataFrame
print(df.tail())
# Out:
#          Date Revenue
# 0  2010-09-30      31
# 1  2010-06-30      28
# 2  2010-03-31      21
# 3  2009-09-30      46
# 4  2009-09-30      27

# %% [markdown]
# ### GME STOCKS ANALYSIS

# %%
import yfinance as yf
tesla = yf.Ticker('TSLA')
tesla_data=tesla.history(period="max")
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# ### GME REVENUE

# %%
import pandas as pd

# Sample HTML content
html_data = '''
<table cellpadding="1" cellspacing="1" border="0" width="100%">
  <tbody>
    <tr>
      <th>Date</th>
      <th>Revenue</th>
    </tr>
    <tr>
      <td>2006-01-31</td>
      <td>1667</td>
    </tr>
    <tr>
      <td>2005-10-31</td>
      <td>534</td>
    </tr>
    <tr>
      <td>2005-07-31</td>
      <td>416</td>
    </tr>
    <tr>
      <td>2005-04-30</td>
      <td>475</td>
    </tr>
    <tr>
      <td>2005-01-31</td>
      <td>709</td>
    </tr>
  </tbody>
</table>
'''

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Extracting the table data
table_data = soup.find('table')
rows = table_data.find_all('tr')

# Creating an empty list to store revenue data
gme_revenue = []
for row in rows[1:]:
  # Extract date and revenue data from each row
  date = row.find_all('td')[0].text.strip()
  revenue = row.find_all('td')[1].text.strip()
  # Append data to the gme_revenue list
  gme_revenue.append([date, revenue])

# Creating a Pandas DataFrame
df = pd.DataFrame(gme_revenue, columns=['Date', 'Revenue'])

# Displaying the last five rows of the DataFrame
print(df.tail())
# Out:
#          Date Revenue
# 0  2006-01-31    1667
# 1  2005-10-31     534
# 2  2005-07-31     416
# 3  2005-04-30     475
# 4  2005-01-31     709

# %% [markdown]
# ### tesla Graph

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the ticker symbol
ticker_symbol = "TSLA"

# Define the start and end dates for the data
start_date = "2020-01-01"
end_date = "2024-01-01"

# Fetch the data
tesla_data = yf.download(ticker_symbol, start=start_date, end=end_date)

# Reset the index
tesla_data.reset_index(inplace=True)

# Call the make_graph function
make_graph(tesla_data, title="Tesla Stock Data")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### GME Graph

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the ticker symbol
ticker_symbol = "GME"

# Define the start and end dates for the data
start_date = "2020-01-01"
end_date = "2024-01-01"

# Fetch the data
tesla_data = yf.download(ticker_symbol, start=start_date, end=end_date)

# Reset the index
tesla_data.reset_index(inplace=True)

# Call the make_graph function
make_graph(tesla_data, title="GAMESTOP STOCK")
# Out:
# [*********************100%%**********************]  1 of 1 completed
